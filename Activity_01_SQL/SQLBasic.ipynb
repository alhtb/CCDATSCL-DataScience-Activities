# %% [markdown]
# ### **Basic SQL**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Cities.csv**, **Countries.csv**, **Players.csv**, and **Teams.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# !pip install prettytable==0.7.2
# !pip install ipython-sql
# Out:
# Collecting prettytable==0.7.2
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13695 sha256=30ab18738e667404377030b4bb3245530eb89d787cf306e475bc5d58d513cdca
#   Stored in directory: /root/.cache/pip/wheels/ca/f9/66/1ebeb8cdff2211eebb6fce02957f9e0a9ae3da4b7e65512d1b
# Successfully built prettytable
# Installing collected packages: prettytable
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
# Successfully installed prettytable-0.7.2
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (2.0.45)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipython-sql)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-sql) (0.2.14)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.6 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2

# %%
# Set-up
# %load_ext sql
# %sql sqlite://
import pandas as pd

# %%
# Create database tables from CSV files
with open('Cities.csv') as f: Cities = pd.read_csv(f, index_col=0)
# %sql drop table if exists Cities;
# %sql --persist Cities


with open('Countries.csv') as f: Countries = pd.read_csv(f, index_col=0)
# %sql drop table if exists Countries;
# %sql --persist Countries
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted countries'

# %% [markdown]
# #### Look at sample of Cities and Countries tables

# %%
# %%sql
# select * from Cities limit 5
# Out:
#  * sqlite://
# Done.
# [('Aalborg', 'Denmark', 57.03, 9.92, 7.52),
#  ('Aberdeen', 'United Kingdom', 57.17, -2.08, 8.1),
#  ('Abisko', 'Sweden', 63.35, 18.83, 0.2),
#  ('Adana', 'Turkey', 36.99, 35.32, 18.67),
#  ('Albacete', 'Spain', 39.0, -1.87, 12.62)]

# %%
# %%sql
# select * from Countries limit 5
# Out:
#  * sqlite://
# Done.
# [('Albania', 2.9, 'no', 'yes'),
#  ('Andorra', 0.07, 'no', 'no'),
#  ('Austria', 8.57, 'yes', 'no'),
#  ('Belarus', 9.48, 'no', 'no'),
#  ('Belgium', 11.37, 'yes', 'yes')]

# %% [markdown]
# ### Basic Select statement
# Select columns
# From tables
# Where condition

# %% [markdown]
# *Find all countries not in the EU*

# %%
# %%sql
# select country
# from Countries
# where EU = 'no'
# Out:
#  * sqlite://
# Done.
# [('Albania',),
#  ('Andorra',),
#  ('Belarus',),
#  ('Bosnia and Herzegovina',),
#  ('Iceland',),
#  ('Kosovo',),
#  ('Liechtenstein',),
#  ('Macedonia',),
#  ('Moldova',),
#  ('Montenegro',),
#  ('Norway',),
#  ('Serbia',),
#  ('Switzerland',),
#  ('Turkey',),
#  ('Ukraine',)]

# %% [markdown]
# *Find all cities with temperature between -5 and 5; return city, country, and temperature*

# %%
# %%sql
# select city, country, temperature
# from Cities
# where temperature > -5 and temperature < 5
# Out:
#  * sqlite://
# Done.
# [('Abisko', 'Sweden', 0.2),
#  ('Augsburg', 'Germany', 4.54),
#  ('Bergen', 'Norway', 1.75),
#  ('Bodo', 'Norway', 4.5),
#  ('Helsinki', 'Finland', 4.19),
#  ('Innsbruck', 'Austria', 4.54),
#  ('Kiruna', 'Sweden', -2.2),
#  ('Orsha', 'Belarus', 4.93),
#  ('Oslo', 'Norway', 2.32),
#  ('Oulu', 'Finland', 1.45),
#  ('Salzburg', 'Austria', 4.62),
#  ('Tallinn', 'Estonia', 4.82),
#  ('Tampere', 'Finland', 3.59),
#  ('Tartu', 'Estonia', 4.36),
#  ('Trondheim', 'Norway', 4.53),
#  ('Turku', 'Finland', 4.72),
#  ('Uppsala', 'Sweden', 4.17)]

# %% [markdown]
# ### Ordering

# %% [markdown]
# *Modify previous query to sort by temperature*

# %%
# %%sql
# select city, country, temperature
# from Cities
# where temperature > -5 and temperature < 5
# order by temperature
# Out:
#  * sqlite://
# Done.
# [('Kiruna', 'Sweden', -2.2),
#  ('Abisko', 'Sweden', 0.2),
#  ('Oulu', 'Finland', 1.45),
#  ('Bergen', 'Norway', 1.75),
#  ('Oslo', 'Norway', 2.32),
#  ('Tampere', 'Finland', 3.59),
#  ('Uppsala', 'Sweden', 4.17),
#  ('Helsinki', 'Finland', 4.19),
#  ('Tartu', 'Estonia', 4.36),
#  ('Bodo', 'Norway', 4.5),
#  ('Trondheim', 'Norway', 4.53),
#  ('Augsburg', 'Germany', 4.54),
#  ('Innsbruck', 'Austria', 4.54),
#  ('Salzburg', 'Austria', 4.62),
#  ('Turku', 'Finland', 4.72),
#  ('Tallinn', 'Estonia', 4.82),
#  ('Orsha', 'Belarus', 4.93)]

# %% [markdown]
# *Modify previous query to sort by country, then temperature descending*

# %%
# %%sql
# select city, country, temperature
# from Cities
# where temperature > -5 and temperature < 5
# order by country ASC, temperature DESC
# Out:
#  * sqlite://
# Done.
# [('Salzburg', 'Austria', 4.62),
#  ('Innsbruck', 'Austria', 4.54),
#  ('Orsha', 'Belarus', 4.93),
#  ('Tallinn', 'Estonia', 4.82),
#  ('Tartu', 'Estonia', 4.36),
#  ('Turku', 'Finland', 4.72),
#  ('Helsinki', 'Finland', 4.19),
#  ('Tampere', 'Finland', 3.59),
#  ('Oulu', 'Finland', 1.45),
#  ('Augsburg', 'Germany', 4.54),
#  ('Trondheim', 'Norway', 4.53),
#  ('Bodo', 'Norway', 4.5),
#  ('Oslo', 'Norway', 2.32),
#  ('Bergen', 'Norway', 1.75),
#  ('Uppsala', 'Sweden', 4.17),
#  ('Abisko', 'Sweden', 0.2),
#  ('Kiruna', 'Sweden', -2.2)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %% [markdown]
# *Find all countries with no coastline and with population > 9. Return the country and population, in descending order of population.*

# %%
# %%sql
# select country, population
# from Countries
# where coastline = "no" and population > 9
# order by population DESC
# Out:
#  * sqlite://
# Done.
# [('Czech Republic', 10.55), ('Hungary', 9.82), ('Belarus', 9.48)]

# %% [markdown]
# ### Multiple tables in From clause - Joins

# %% [markdown]
# *Find all cities with longitude < 10 not in the EU, return city and longitude*

# %%
Cities.head(2) # python command = dataframe
# Out:
#                  country  latitude  longitude  temperature
# city
# Aalborg          Denmark     57.03       9.92         7.52
# Aberdeen  United Kingdom     57.17      -2.08         8.10

# %%
Countries.head(2)
# Out:
#          population  EU coastline
# country
# Albania        2.90  no       yes
# Andorra        0.07  no        no

# %%
# %%sql
# select city, longitude
# from Cities, Countries -- 2 tables
# where Cities.country = Countries.country -- get data from the two tables.
# and longitude < 10 and EU = 'no' -- this are their conditions
#
# -- SQL: comment "--"
# Out:
#  * sqlite://
# Done.
# [('Andorra', 1.52),
#  ('Basel', 7.59),
#  ('Bergen', 5.32),
#  ('Geneva', 6.14),
#  ('Stavanger', 5.68),
#  ('Zurich', 8.56)]

# %% [markdown]
# *Modify previous query to also return country (error then fix)*

# %%
# %%sql
# select city, longitude, Cities.country
# from Cities, Countries
# where Cities.country = Countries.country -- if they have the same field name. put the table name in the select if you need to display it.
# and longitude < 10 and EU = 'no'
# Out:
#  * sqlite://
# Done.
# [('Andorra', 1.52, 'Andorra'),
#  ('Basel', 7.59, 'Switzerland'),
#  ('Bergen', 5.32, 'Norway'),
#  ('Geneva', 6.14, 'Switzerland'),
#  ('Stavanger', 5.68, 'Norway'),
#  ('Zurich', 8.56, 'Switzerland')]

# %% [markdown]
# *Find all cities with latitude < 50 in a country with population < 5; return city, country, and population, sorted by country*

# %%
# %%sql
# select city, Cities.country, population
# from Cities, Countries
# where Cities.country = Countries.country
# and latitude < 50 and population < 5
# order by Cities.country
# Out:
#  * sqlite://
# Done.
# [('Elbasan', 'Albania', 2.9),
#  ('Andorra', 'Andorra', 0.07),
#  ('Sarajevo', 'Bosnia and Herzegovina', 3.8),
#  ('Rijeka', 'Croatia', 4.23),
#  ('Split', 'Croatia', 4.23),
#  ('Skopje', 'Macedonia', 2.08),
#  ('Balti', 'Moldova', 4.06),
#  ('Chisinau', 'Moldova', 4.06),
#  ('Podgorica', 'Montenegro', 0.63),
#  ('Ljubljana', 'Slovenia', 2.07)]

# %% [markdown]
# #### Inner Join -- just FYI

# %% [markdown]
# *Same query as above*

# %%
# %%sql
# select city, Cities.country, population
# from Cities inner join Countries
#      on Cities.country = Countries.country -- condition of the INNER JOIN.
# where latitude < 50 and population < 5
# order by Cities.country
# Out:
#  * sqlite://
# Done.
# [('Elbasan', 'Albania', 2.9),
#  ('Andorra', 'Andorra', 0.07),
#  ('Sarajevo', 'Bosnia and Herzegovina', 3.8),
#  ('Rijeka', 'Croatia', 4.23),
#  ('Split', 'Croatia', 4.23),
#  ('Skopje', 'Macedonia', 2.08),
#  ('Balti', 'Moldova', 4.06),
#  ('Chisinau', 'Moldova', 4.06),
#  ('Podgorica', 'Montenegro', 0.63),
#  ('Ljubljana', 'Slovenia', 2.07)]

# %% [markdown]
# ### Select *

# %% [markdown]
# *Modify previous queries to return all columns*

# %%
# %%sql
# select *
# from Cities inner join Countries
#      on Cities.country = Countries.country -- condition of the INNER JOIN.
# where latitude < 50 and population < 5
# order by Cities.country
# Out:
#  * sqlite://
# Done.
# [('Elbasan', 'Albania', 41.12, 20.08, 15.18, 'Albania', 2.9, 'no', 'yes'),
#  ('Andorra', 'Andorra', 42.5, 1.52, 9.6, 'Andorra', 0.07, 'no', 'no'),
#  ('Sarajevo', 'Bosnia and Herzegovina', 43.85, 13.38, 9.6, 'Bosnia and Herzegovina', 3.8, 'no', 'yes'),
#  ('Rijeka', 'Croatia', 45.33, 14.45, 9.27, 'Croatia', 4.23, 'yes', 'yes'),
#  ('Split', 'Croatia', 43.52, 16.47, 12.46, 'Croatia', 4.23, 'yes', 'yes'),
#  ('Skopje', 'Macedonia', 42.0, 21.43, 9.36, 'Macedonia', 2.08, 'no', 'no'),
#  ('Balti', 'Moldova', 47.76, 27.91, 8.23, 'Moldova', 4.06, 'no', 'no'),
#  ('Chisinau', 'Moldova', 47.01, 28.86, 8.6, 'Moldova', 4.06, 'no', 'no'),
#  ('Podgorica', 'Montenegro', 42.47, 19.27, 9.99, 'Montenegro', 0.63, 'no', 'yes'),
#  ('Ljubljana', 'Slovenia', 46.06, 14.51, 9.27, 'Slovenia', 2.07, 'yes', 'yes')]

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %% [markdown]
# *Find all cities with latitude > 45 in a country with no coastline and with population > 9. Return the city, country, latitude, and whether it's in the EU.*

# %%
# %%sql
# select city, Cities.country as country, latitude, EU
# from Cities, Countries
# where Cities.country = Countries.country
# and latitude > 45 and coastline = "no" and population > 9
# Out:
#  * sqlite://
# Done.
# [('Brest', 'Belarus', 52.1, 'no'),
#  ('Brno', 'Czech Republic', 49.2, 'yes'),
#  ('Budapest', 'Hungary', 47.5, 'yes'),
#  ('Debrecen', 'Hungary', 47.53, 'yes'),
#  ('Gyor', 'Hungary', 47.7, 'yes'),
#  ('Hrodna', 'Belarus', 53.68, 'no'),
#  ('Mazyr', 'Belarus', 52.05, 'no'),
#  ('Minsk', 'Belarus', 53.9, 'no'),
#  ('Orsha', 'Belarus', 54.52, 'no'),
#  ('Ostrava', 'Czech Republic', 49.83, 'yes'),
#  ('Pinsk', 'Belarus', 52.13, 'no'),
#  ('Prague', 'Czech Republic', 50.08, 'yes'),
#  ('Szeged', 'Hungary', 46.25, 'yes')]

# %% [markdown]
# ### Aggregation and Grouping

# %% [markdown]
# *Find the average temperature for all cities*

# %%
# %%sql
# select avg(temperature) as avgTemp
# from Cities
# Out:
#  * sqlite://
# Done.
# [(9.497840375586858,)]

# %% [markdown]
# *Modify previous query to find average temperature of cities with latitude > 55*

# %%
# %%sql
# select avg(temperature)
# from Cities
# where latitude > 55
# Out:
#  * sqlite://
# Done.
# [(4.985185185185185,)]

# %% [markdown]
# *Modify previous query to also find minimum and maxiumum temperature of cities with latitude > 55*

# %%
# %%sql
# select avg(temperature), min(temperature) as Min_val, max(temperature) as Max_val
# from Cities
# where latitude > 55
# Out:
#  * sqlite://
# Done.
# [(4.985185185185185, -2.2, 8.6)]

# %% [markdown]
# *Modify previous query to return number of cities with latitude > 55*

# %%
# %%sql
# select count(city) as num_cities
# from Cities
# where latitude > 55
# Out:
#  * sqlite://
# Done.
# [(27,)]

# %% [markdown]
# *Rename result column as northerns*

# %%
# %%sql
# select count(city) as northerns
# from Cities
# where latitude > 55
# Out:
#  * sqlite://
# Done.
# [(27,)]

# %%
Cities.head(1)
# Out:
#          country  latitude  longitude  temperature
# city
# Aalborg  Denmark     57.03       9.92         7.52

# %%
Countries.head(1)
# Out:
#          population  EU coastline
# country
# Albania         2.9  no       yes

# %% [markdown]
# *Find the minimum and maximum temperature of cities in the EU (then not in the EU)*

# %%
# %%sql
# select EU, min(temperature), max(temperature)
# from Cities, Countries
# where Cities.country = Countries.Country
# group by EU
# Out:
#  * sqlite://
# Done.
# [('no', 1.75, 18.67), ('yes', -2.2, 17.9)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %% [markdown]
# *Find the number of cities with latitude > 45 in countries with no coastline and with population > 9; also return the minimum and maximum latitude among those cities*

# %%
# %%sql
# select count(city) as num_cities, min(latitude) as min_latitude, max(latitude) as max_latitude
# from Cities, Countries
# where Cities.country = Countries.country
# and latitude > 45 and coastline = "no" and population > 9
# Out:
#  * sqlite://
# Done.
# [(13, 46.25, 54.52)]

# %% [markdown]
# *Find the average temperature for each country*

# %%
# %%sql
# select country, avg(temperature)
# from Cities
# group by country
# Out:
#  * sqlite://
# Done.
# [('Albania', 15.18),
#  ('Andorra', 9.6),
#  ('Austria', 6.144),
#  ('Belarus', 5.946666666666666),
#  ('Belgium', 9.65),
#  ('Bosnia and Herzegovina', 9.6),
#  ('Bulgaria', 10.44),
#  ('Croatia', 10.865),
#  ('Czech Republic', 7.8566666666666665),
#  ('Denmark', 7.625),
#  ('Estonia', 4.59),
#  ('Finland', 3.4875),
#  ('France', 10.151111111111112),
#  ('Germany', 7.869285714285714),
#  ('Greece', 16.9025),
#  ('Hungary', 9.6025),
#  ('Ireland', 9.299999999999999),
#  ('Italy', 13.474666666666668),
#  ('Latvia', 5.27),
#  ('Lithuania', 6.1433333333333335),
#  ('Macedonia', 9.36),
#  ('Moldova', 8.415),
#  ('Montenegro', 9.99),
#  ('Netherlands', 8.756666666666668),
#  ('Norway', 3.7260000000000004),
#  ('Poland', 7.250000000000002),
#  ('Portugal', 14.469999999999999),
#  ('Romania', 9.224444444444444),
#  ('Serbia', 9.85),
#  ('Slovakia', 8.48),
#  ('Slovenia', 9.27),
#  ('Spain', 14.238333333333332),
#  ('Sweden', 3.5866666666666673),
#  ('Switzerland', 7.253333333333333),
#  ('Turkey', 11.726666666666665),
#  ('Ukraine', 7.420000000000002),
#  ('United Kingdom', 8.649999999999999)]

# %% [markdown]
# *Modify previous query to sort by descending average temperature*

# %%
# %%sql
# select country, avg(temperature)
# from Cities
# group by country
# sort by avg(temperature) DESC
# Out:
#  * sqlite://
# (sqlite3.OperationalError) near "sort": syntax error
# [SQL: select country, avg(temperature)
# from Cities
# group by country
# sort by avg(temperature) DESC]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# *Modify previous query to show countries only*

# %%
# %%sql
# select country
# from Cities
# group by country
# order by avg(temperature) DESC
# Out:
#  * sqlite://
# Done.
# [('Greece',),
#  ('Albania',),
#  ('Portugal',),
#  ('Spain',),
#  ('Italy',),
#  ('Turkey',),
#  ('Croatia',),
#  ('Bulgaria',),
#  ('France',),
#  ('Montenegro',),
#  ('Serbia',),
#  ('Belgium',),
#  ('Hungary',),
#  ('Bosnia and Herzegovina',),
#  ('Andorra',),
#  ('Macedonia',),
#  ('Ireland',),
#  ('Slovenia',),
#  ('Romania',),
#  ('Netherlands',),
#  ('United Kingdom',),
#  ('Slovakia',),
#  ('Moldova',),
#  ('Germany',),
#  ('Czech Republic',),
#  ('Denmark',),
#  ('Ukraine',),
#  ('Switzerland',),
#  ('Poland',),
#  ('Austria',),
#  ('Lithuania',),
#  ('Belarus',),
#  ('Latvia',),
#  ('Estonia',),
#  ('Norway',),
#  ('Sweden',),
#  ('Finland',)]

# %% [markdown]
# *Find the average temperature for cities in countries with and without coastline*

# %%
# %%sql
# select coastline, avg(temperature)
# from Cities, Countries
# where Cities.country = Countries.country
# group by coastline
# Out:
#  * sqlite://
# Done.
# [('no', 7.748000000000001), ('yes', 9.784699453551914)]

# %% [markdown]
# *Modify previous query to find the average temperature for cities in the EU and not in the EU, then all combinations of coastline and EU*

# %%
# %%sql
# select EU, avg(temperature)
# from Cities, Countries
# where Cities.country = Countries.country
# group by EU
# Out:
#  * sqlite://
# Done.
# [('no', 9.030476190476188), ('yes', 9.694133333333333)]

# %%
# %%sql
# select EU, coastline, avg(temperature)
# from Cities, Countries
# where Cities.country = Countries.country
# group by EU, coastline
# Out:
#  * sqlite://
# Done.
# [('no', 'no', 7.67375),
#  ('no', 'yes', 9.492340425531914),
#  ('yes', 'no', 7.832857142857144),
#  ('yes', 'yes', 9.885735294117652)]

# %% [markdown]
# *Modify previous query to only include cities with latitude < 50, then latitude < 40*

# %%
# %%sql
# select EU, coastline, avg(temperature)
# from Cities, Countries
# where Cities.country = Countries.country
# and latitude < 50
# group by EU, coastline
# Out:
#  * sqlite://
# Done.
# [('no', 'no', 8.709999999999999),
#  ('no', 'yes', 10.675675675675675),
#  ('yes', 'no', 7.816153846153847),
#  ('yes', 'yes', 11.928076923076924)]

# %%
# %%sql
# select EU, coastline, avg(temperature)
# from Cities, Countries
# where Cities.country = Countries.country
# and latitude < 40
# group by EU, coastline
# Out:
#  * sqlite://
# Done.
# [('no', 'yes', 11.766875), ('yes', 'yes', 16.320555555555554)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %% [markdown]
# *For each country in the EU, find the latitude of the northernmost city in the country, i.e., the maximum latitude. Return the country and its maximum latitude, in descending order of maximum latitude.*

# %%
# %%sql
# select Cities.country, max(latitude) as max_latitude
# from Cities, Countries
# where Cities.country = Countries.country
# and EU = 'yes'
# group by Cities.country
# order by max_latitude DESC
# Out:
#  * sqlite://
# Done.
# [('Sweden', 67.85),
#  ('Finland', 65.0),
#  ('Estonia', 59.43),
#  ('United Kingdom', 57.47),
#  ('Denmark', 57.03),
#  ('Latvia', 56.95),
#  ('Lithuania', 55.72),
#  ('Poland', 54.2),
#  ('Germany', 54.07),
#  ('Ireland', 53.33),
#  ('Netherlands', 53.22),
#  ('Belgium', 51.22),
#  ('France', 50.65),
#  ('Czech Republic', 50.08),
#  ('Slovakia', 48.73),
#  ('Austria', 48.32),
#  ('Romania', 47.75),
#  ('Hungary', 47.7),
#  ('Slovenia', 46.06),
#  ('Italy', 45.7),
#  ('Croatia', 45.33),
#  ('Bulgaria', 43.85),
#  ('Spain', 43.38),
#  ('Portugal', 41.55),
#  ('Greece', 39.56)]

# %% [markdown]
# #### A Bug in SQLite - just FYI

# %%
# %%sql
# select country, avg(temperature)
# from Cities
# group by country
# Out:
#  * sqlite://
# Done.
# [('Albania', 15.18),
#  ('Andorra', 9.6),
#  ('Austria', 6.144),
#  ('Belarus', 5.946666666666666),
#  ('Belgium', 9.65),
#  ('Bosnia and Herzegovina', 9.6),
#  ('Bulgaria', 10.44),
#  ('Croatia', 10.865),
#  ('Czech Republic', 7.8566666666666665),
#  ('Denmark', 7.625),
#  ('Estonia', 4.59),
#  ('Finland', 3.4875),
#  ('France', 10.151111111111112),
#  ('Germany', 7.869285714285714),
#  ('Greece', 16.9025),
#  ('Hungary', 9.6025),
#  ('Ireland', 9.299999999999999),
#  ('Italy', 13.474666666666668),
#  ('Latvia', 5.27),
#  ('Lithuania', 6.1433333333333335),
#  ('Macedonia', 9.36),
#  ('Moldova', 8.415),
#  ('Montenegro', 9.99),
#  ('Netherlands', 8.756666666666668),
#  ('Norway', 3.7260000000000004),
#  ('Poland', 7.250000000000002),
#  ('Portugal', 14.469999999999999),
#  ('Romania', 9.224444444444444),
#  ('Serbia', 9.85),
#  ('Slovakia', 8.48),
#  ('Slovenia', 9.27),
#  ('Spain', 14.238333333333332),
#  ('Sweden', 3.5866666666666673),
#  ('Switzerland', 7.253333333333333),
#  ('Turkey', 11.726666666666665),
#  ('Ukraine', 7.420000000000002),
#  ('United Kingdom', 8.649999999999999)]

# %% [markdown]
# *Modify previous query - add city to Select clause*

# %%
# %%sql
# select country, city, avg(temperature)
# from Cities
# group by country
# Out:
#  * sqlite://
# Done.
# [('Albania', 'Elbasan', 15.18),
#  ('Andorra', 'Andorra', 9.6),
#  ('Austria', 'Graz', 6.144),
#  ('Belarus', 'Brest', 5.946666666666666),
#  ('Belgium', 'Brugge', 9.65),
#  ('Bosnia and Herzegovina', 'Sarajevo', 9.6),
#  ('Bulgaria', 'Burgas', 10.44),
#  ('Croatia', 'Rijeka', 10.865),
#  ('Czech Republic', 'Brno', 7.8566666666666665),
#  ('Denmark', 'Aalborg', 7.625),
#  ('Estonia', 'Tallinn', 4.59),
#  ('Finland', 'Helsinki', 3.4875),
#  ('France', 'Amiens', 10.151111111111112),
#  ('Germany', 'Augsburg', 7.869285714285714),
#  ('Greece', 'Athens', 16.9025),
#  ('Hungary', 'Budapest', 9.6025),
#  ('Ireland', 'Cork', 9.299999999999999),
#  ('Italy', 'Ancona', 13.474666666666668),
#  ('Latvia', 'Daugavpils', 5.27),
#  ('Lithuania', 'Kaunas', 6.1433333333333335),
#  ('Macedonia', 'Skopje', 9.36),
#  ('Moldova', 'Balti', 8.415),
#  ('Montenegro', 'Podgorica', 9.99),
#  ('Netherlands', 'Amsterdam', 8.756666666666668),
#  ('Norway', 'Bergen', 3.7260000000000004),
#  ('Poland', 'Bialystok', 7.250000000000002),
#  ('Portugal', 'Braga', 14.469999999999999),
#  ('Romania', 'Arad', 9.224444444444444),
#  ('Serbia', 'Belgrade', 9.85),
#  ('Slovakia', 'Bratislava', 8.48),
#  ('Slovenia', 'Ljubljana', 9.27),
#  ('Spain', 'Albacete', 14.238333333333332),
#  ('Sweden', 'Abisko', 3.5866666666666673),
#  ('Switzerland', 'Basel', 7.253333333333333),
#  ('Turkey', 'Adana', 11.726666666666665),
#  ('Ukraine', 'Bila Tserkva', 7.420000000000002),
#  ('United Kingdom', 'Aberdeen', 8.649999999999999)]

# %% [markdown]
# *Now focus on Austria and Sweden*

# %%
# %%sql
# select *
# from Cities
# where country = 'Austria' or country = 'Sweden'
# order by country
# Out:
#  * sqlite://
# Done.
# [('Graz', 'Austria', 47.08, 15.41, 6.91),
#  ('Innsbruck', 'Austria', 47.28, 11.41, 4.54),
#  ('Linz', 'Austria', 48.32, 14.29, 6.79),
#  ('Salzburg', 'Austria', 47.81, 13.04, 4.62),
#  ('Vienna', 'Austria', 48.2, 16.37, 7.86),
#  ('Abisko', 'Sweden', 63.35, 18.83, 0.2),
#  ('Göteborg', 'Sweden', 57.75, 12.0, 5.76),
#  ('Kiruna', 'Sweden', 67.85, 20.22, -2.2),
#  ('Malmö', 'Sweden', 55.58, 13.03, 7.33),
#  ('Stockholm', 'Sweden', 59.35, 18.1, 6.26),
#  ('Uppsala', 'Sweden', 59.86, 17.64, 4.17)]

# %%
# %%sql
# select country, city, avg(temperature)
# from Cities
# where country = 'Austria' or country = 'Sweden'
# group by country
# Out:
#  * sqlite://
# Done.
# [('Austria', 'Graz', 6.144), ('Sweden', 'Abisko', 3.5866666666666673)]

# %% [markdown]
# *Modify previous query to min(temperature), max(temperature), then together in both orders*

# %%
# %%sql
# select country, city, min(temperature)
# from Cities
# where country = 'Austria' or country = 'Sweden'
# group by country
# Out:
#  * sqlite://
# Done.
# [('Austria', 'Innsbruck', 4.54), ('Sweden', 'Kiruna', -2.2)]

# %%
# %%sql
# select country, city, max(temperature)
# from Cities
# where country = 'Austria' or country = 'Sweden'
# group by country
# Out:
#  * sqlite://
# Done.
# [('Austria', 'Vienna', 7.86), ('Sweden', 'Malmö', 7.33)]

# %%
# %%sql
# select country, city, min(temperature), max(temperature)
# from Cities
# where country = 'Austria' or country = 'Sweden'
# group by country
# Out:
#  * sqlite://
# Done.
# [('Austria', 'Vienna', 4.54, 7.86), ('Sweden', 'Malmö', -2.2, 7.33)]

# %% [markdown]
# ### The Limit clause

# %% [markdown]
# *Return any three countries with population > 20*

# %%
# %%sql
# select country
# from Countries
# where population > 20
# limit 3
# Out:
#  * sqlite://
# Done.
# [('France',), ('Germany',), ('Italy',)]

# %% [markdown]
# *Find the ten coldest cities*

# %%
# %%sql
# select city, temperature
# from Cities
# order by temperature
# limit 10
# Out:
#  * sqlite://
# Done.
# [('Kiruna', -2.2),
#  ('Abisko', 0.2),
#  ('Oulu', 1.45),
#  ('Bergen', 1.75),
#  ('Oslo', 2.32),
#  ('Tampere', 3.59),
#  ('Uppsala', 4.17),
#  ('Helsinki', 4.19),
#  ('Tartu', 4.36),
#  ('Bodo', 4.5)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %% [markdown]
# *Find the five easternmost (greatest longitude) cities in countries with no coastline. Return the city and country names.*

# %%
# %%sql
# select city, Cities.country
# from Cities, Countries
# where Cities.country = Countries.country
# and coastline = "no"
# order by longitude DESC
# limit 5
# Out:
#  * sqlite://
# Done.
# [('Orsha', 'Belarus'),
#  ('Mazyr', 'Belarus'),
#  ('Chisinau', 'Moldova'),
#  ('Balti', 'Moldova'),
#  ('Minsk', 'Belarus')]

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Basic SQL on World Cup Data**</font>

# %%
# Create database tables from CSV files
with open('Players.csv') as f: Players = pd.read_csv(f, index_col=0)
# %sql drop table if exists Players;
# %sql --persist Players
with open('Teams.csv') as f: Teams = pd.read_csv(f, index_col=0)
# %sql drop table if exists Teams;
# %sql --persist Teams
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted teams'

# %% [markdown]
# #### Look at sample of Players and Teams tables

# %%
# %%sql
# select * from Players limit 5
# Out:
#  * sqlite://
# Done.
# [('Abdoun', 'Algeria', 'midfielder', 16, 0, 6, 0, 0),
#  ('Belhadj', 'Algeria', 'defender', 270, 1, 146, 8, 0),
#  ('Boudebouz', 'Algeria', 'midfielder', 74, 3, 28, 1, 0),
#  ('Bougherra', 'Algeria', 'defender', 270, 1, 89, 11, 0),
#  ('Chaouchi', 'Algeria', 'goalkeeper', 90, 0, 17, 0, 2)]

# %%
# %%sql
# select * from Teams limit 5
# Out:
#  * sqlite://
# Done.
# [('Brazil', 1, 5, 3, 1, 1, 9, 4, 7, 2),
#  ('Spain', 2, 6, 5, 0, 1, 7, 2, 3, 0),
#  ('Portugal', 3, 4, 1, 2, 1, 7, 1, 8, 1),
#  ('Netherlands', 4, 6, 6, 0, 0, 12, 5, 15, 0),
#  ('Italy', 5, 3, 0, 2, 1, 4, 5, 5, 0)]

# %% [markdown]
# *1)  What player on a team with “ia” in the team name played less than 200 minutes and made more than 100 passes? Return the player surname. Note: To check if attribute A contains string S use "A like '%S%'"*

# %%
# %%sql
# select surname
# from Players
# where team like "%ia%"
# and minutes < 200 and passes >100
# Out:
#  * sqlite://
# Done.
# [('Kuzmanovic',)]

# %% [markdown]
# *2) Find all players who took more than 20 shots. Return all player information in descending order of shots taken.*

# %%
# %%sql
# select *
# from Players
# where shots > 20
# order by shots DESC
# Out:
#  * sqlite://
# Done.
# [('Gyan', 'Ghana', 'forward', 501, 27, 151, 1, 0),
#  ('Villa', 'Spain', 'forward', 529, 22, 169, 2, 0),
#  ('Messi', 'Argentina', 'forward', 450, 21, 321, 10, 0)]

# %% [markdown]
# *3) Find the goalkeepers of teams that played more than four games. List the surname of the goalkeeper, the team, and the number of minutes the goalkeeper played.*

# %%
# %%sql
# select surname, Players.team, minutes
# from Players, Teams
# where Players.team = Teams.team
# and position = "goalkeeper" and games > 4
# Out:
#  * sqlite://
# Done.
# [('Romero', 'Argentina', 450),
#  ('Julio Cesar', 'Brazil', 450),
#  ('Neuer', 'Germany', 540),
#  ('Kingson', 'Ghana', 510),
#  ('Stekelenburg', 'Netherlands', 540),
#  ('Villar', 'Paraguay', 480),
#  ('Casillas', 'Spain', 540),
#  ('Muslera', 'Uruguay', 570)]

# %% [markdown]
# *4) How many players who play on a team with ranking <10 played more than 350 minutes? Return one number in a column named 'superstar'.*

# %%
# %%sql
# select count(surname) as Superstar
# from Players, Teams
# where Players.team = Teams.team
# and ranking < 10 and minutes > 350
# Out:
#  * sqlite://
# Done.
# [(54,)]

# %% [markdown]
# *5) What is the average number of passes made by forwards? By midfielders? Write one query that gives both values with the corresponding position.*

# %%
# %%sql
# select position, avg(passes)
# from Players
# where position = "forward" or position = "midfielder"
# group by position
# Out:
#  * sqlite://
# Done.
# [('forward', 50.82517482517483), ('midfielder', 95.2719298245614)]

# %% [markdown]
# *6) Which team has the highest ratio of goalsFor to goalsAgainst? Return the team and the ratio.*

# %%
# %%sql
# select team, cast(goalsFor as float) / goalsAgainst as ratio
# from Teams
# order by ratio DESC
# limit 1
# Out:
#  * sqlite://
# Done.
# [('Portugal', 7.0)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn Extra - Basic SQL on Titanic Data**</font>

# %% [markdown]
# <font color="red">File access required:</font> In Colab these extra problems require first uploading **Titanic.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure this file is in the same workspace as the notebook.

# %%
# Create database table from CSV file
with open('Titanic.csv') as f: Titanic = pd.read_csv(f, index_col=0)
# %sql drop table if exists Titanic;
# %sql --persist Titanic
# Out:
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted titanic'

# %% [markdown]
# #### Look at sample of Titanic table

# %%
# %%sql
# select * from Titanic limit 5
# Out:
#  * sqlite://
# Done.
# [('Abbing', 'Mr. Anthony', 'M', 42.0, 3, 7.55, 'Southampton', 'no'),
#  ('Abbott', 'Mrs. Stanton (Rosa Hunt)', 'F', 35.0, 3, 20.25, 'Southampton', 'yes'),
#  ('Abbott', 'Mr. Rossmore Edward', 'M', 16.0, 3, 20.25, 'Southampton', 'no'),
#  ('Abelson', 'Mr. Samuel', 'M', 30.0, 2, 24.0, 'Cherbourg', 'no'),
#  ('Abelson', 'Mrs. Samuel (Hannah Wizosky)', 'F', 28.0, 2, 24.0, 'Cherbourg', 'yes')]

# %% [markdown]
# *1) How many passengers sailed for free (i.e, fare is zero)?*

# %%
# %%sql
# select count(last)
# from Titanic
# where fare = 0
# Out:
#  * sqlite://
# Done.
# [(15,)]

# %% [markdown]
# *2) How many married women over age 50 embarked in Cherbourg? (Married women’s first names begin with "Mrs."). Note: To check if attribute A begins with string S use "A like 'S%'"*

# %%
# %%sql
# select count(first)
# from Titanic
# where age > 50 and first like "Mrs.%" and embarked = "Cherbourg"
# Out:
#  * sqlite://
# Done.
# [(4,)]

# %% [markdown]
# *3) Write three queries to find: (i) the total number of passengers; (ii) the number of passengers under 18; (iii) the number of passengers 18 or older. Notice that the second and third numbers don't add up to the first.*

# %%
# %%sql
# select count(last)
# from Titanic
# Out:
#  * sqlite://
# Done.
# [(891,)]

# %%
# %%sql
# select count(last)
# from Titanic
# where age < 18
# Out:
#  * sqlite://
# Done.
# [(113,)]

# %%
# %%sql
# select count(last)
# from Titanic
# where age >= 18
# Out:
#  * sqlite://
# Done.
# [(601,)]

# %% [markdown]
# *Missing values in SQL tables are given a special value called 'null', and conditions 'A is null' and 'A is not null' can be use in Where clauses to check whether attribute A has the 'null' value. Write a query to find the number of passengers whose age is missing -- now your passenger numbers should add up. Modify the query to also return the average fare paid by those passengers.*

# %%
# %%sql
# select count(last)
# from Titanic
# where age is null
# Out:
#  * sqlite://
# Done.
# [(177,)]

# %%
# %%sql
# select count(last), avg(fare)
# from Titanic
# where age is null
# Out:
#  * sqlite://
# Done.
# [(177, 22.159491525423757)]

# %% [markdown]
# *4) Find all passengers whose age is not an integer; return last name, first name, and age, from youngest to oldest. Note: Consider using the round() function*

# %%
# %%sql
# select last, first, age
# from Titanic
# where age != round(age)
# order by age
# Out:
#  * sqlite://
# Done.
# [('Thomas', 'Master Assad Alexander', 0.42),
#  ('Hamalainen', 'Master Viljo', 0.67),
#  ('Baclini', 'Miss Helene Barbara', 0.75),
#  ('Baclini', 'Miss Eugenie', 0.75),
#  ('Caldwell', 'Master Alden Gates', 0.83),
#  ('Richards', 'Master George Sibley', 0.83),
#  ('Allison', 'Master Hudson Trevor', 0.92),
#  ('Zabour', 'Miss Hileni', 14.5),
#  ('Lovell', ' Mr. John Hall ("Henry")', 20.5),
#  ('Hanna', 'Mr. Mansour', 23.5),
#  ('Sawyer', 'Mr. Frederick Charles', 24.5),
#  ('Novel', 'Mr. Mansouer', 28.5),
#  ('Williams', 'Mr. Leslie', 28.5),
#  ('Mangan', 'Miss Mary', 30.5),
#  ('Tomlin', 'Mr. Ernest Portage', 30.5),
#  ('Nasser', 'Mr. Nicholas', 32.5),
#  ('Webber', 'Miss Susan', 32.5),
#  ('Lemberopolous', 'Mr. Peter L', 34.5),
#  ('Navratil', ' Mr. Michel ("Louis M Hoffman")', 36.5),
#  ('Farrell', 'Mr. James', 40.5),
#  ('van Billiard', 'Mr. Austin Blyler', 40.5),
#  ('Partner', 'Mr. Austen', 45.5),
#  ('Youseff', 'Mr. Gerious', 45.5),
#  ('Meo', 'Mr. Alfonzo', 55.5),
#  ('Connors', 'Mr. Patrick', 70.5)]

# %% [markdown]
# *5) What is the most common last name among passengers, and how many passengers have that last name?*

# %%
# %%sql
# select last, count(last)
# from Titanic
# group by last
# order by count(last) DESC
# limit 1
# Out:
#  * sqlite://
# Done.
# [('Andersson', 9)]

# %% [markdown]
# *6) What is the average fare paid by passengers in the three classes, and the average age of passengers in the three classes?*

# %%
# %%sql
# select class, avg(fare), avg(age)
# from Titanic
# group by class
# Out:
#  * sqlite://
# Done.
# [(1, 84.15499999999999, 38.233440860215055),
#  (2, 20.66222826086957, 29.87763005780347),
#  (3, 13.676863543788176, 25.14061971830986)]

# %% [markdown]
# *7) For male survivors, female survivors, male non-survivors, and female non-survivors, how many passengers are in each of those four categories and what is their average fare? Return your results from lowest to highest
# average fare.*

# %%
# %%sql
# select gender, survived, count(gender), avg(fare)
# from Titanic
# group by gender, survived
# order by avg(fare)
# Out:
#  * sqlite://
# Done.
# [('M', 'no', 468, 21.961923076923),
#  ('F', 'no', 81, 23.02555555555556),
#  ('M', 'yes', 109, 40.82229357798166),
#  ('F', 'yes', 233, 51.93901287553647)]
