254', '14164', '245261', '204760', '130072', '3266', '183219', '187318', '23684', '230758', '173452', '227290', '101420', '10028', '45835', '135513', '231073', '7556', '54515', '113170', '228295', '44867', '169713', '28172', '216969', '74289', '42841', '204885', '53303', '105750', '41453', '207848', '136734', '17574', '15638', '199832', '244769', '67073', '142239', '4622', '192136', '117631', '177369', '54810', '10096', '211713', '49251', '120662', '128909', '206673', '18019', '243482', '149321', '192012', '65563', '138903', '81365', '162227', '68470', '135247', '14588', '128859', '116970', '145904', '176170', '3962', '185275', '172112', '87514', '34520', '105122', '147660', '207601', '69551', '104559', '24 ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'2', '5', '4', '1'}
# eggs
# {'4', '3', '1'}
# juice
# {'2', '5', '1'}
# cookies
# {'2', '5'}
# chips
# {'5', '3'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'4', '3', '1'}
# Transactions containing milk: {'2', '5', '4', '1'}
# Transactions containing both: {'4', '1'}
# Number of transactions containing both: 2

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### <font color = 'green'>**FIX VERSION**</font>

# %% [markdown]
# The original code iterated through every item twice without filtering, causing it to print duplicate pairs (like "milk-juice" and "juice-milk") and self-pairs (like "milk-milk").

# %%
for i1 in Sitems:
    for i2 in Sitems:
      # FIX: Check if i1 comes before i2 alphabetically to avoid duplicates and self-pairs
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            print([i1, i2, common])
# Out:
# ['eggs', 'milk', 2]
# ['eggs', 'juice', 1]
# ['juice', 'milk', 3]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
support = 0.03
count_three = 0
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common / Mnumtrans > support:
                    print(i1, '|', i2, '|', i3)
                    count_three += 1
print("Number of frequent item-sets of three:", count_three)
# Out:
# Boyhood | Inside Out | The Imitation Game
# Boyhood | Gone Girl | The Imitation Game
# Boyhood | Gone Girl | Inside Out
# Boyhood | Fury | The Imitation Game
# Boyhood | Fury | Gone Girl
# Big Hero 6 | Boyhood | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl
# Big Hero 6 | Inside Out | The Imitation Game
# Big Hero 6 | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out
# Big Hero 6 | Fury | The Imitation Game
# Big Hero 6 | Fury | Gone Girl
# Gone Girl | Inside Out | The Imitation Game
# Fury | Gone Girl | The Imitation Game
# Number of frequent item-sets of three: 14

# %%
# Frequent item-sets of four
support = 0.03
count_four = 0
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            for i4 in Mitems:
                if i1 < i2 and i2 < i3 and i3 < i4:
                    common = len(Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems[i4])
                    if common / Mnumtrans > support:
                        print(i1, '|', i2, '|', i3, '|', i4)
                        count_four += 1
print("Number of frequent item-sets of four:", count_four)
# Out:
# Boyhood | Gone Girl | Inside Out | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out | The Imitation Game
# Number of frequent item-sets of four: 3

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        common = len(Sitems[lhs[0]] & Sitems[i])
        if common/lhs[1] > confidence:
            print(lhs[0], '->', i)
# Out:
# milk -> milk
# milk -> juice
# eggs -> milk
# eggs -> eggs
# juice -> milk
# juice -> juice
# juice -> cookies

# %% [markdown]
# #### <font color = 'green'>**FIX VERSION**</font>

# %% [markdown]
# The original code iterates through every item without excluding itself, resulting in meaningless self-referential rules (e.g., "milk -> milk") which always have 100% confidence but provide no value.

# %%
confidence = 0.5
for lhs in frequentLHS:
    for i in Sitems:
        # FIX: Ensure LHS and RHS are different items
        if lhs[0] != i:
            common = len(Sitems[lhs[0]] & Sitems[i])
            if common / lhs[1] > confidence:
                print(lhs[0], '->', i)
# Out:
# milk -> juice
# eggs -> milk
# juice -> milk
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining
support = 0.03
confidence = 0.6

# Compute frequent item-sets of three items (LHS candidates)
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])
print('Frequent LHS count:', len(frequentLHS))

# Find RHS items with sufficient confidence
count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            # Intersection of LHS (3 items) and RHS (1 item)
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            conf = common / lhs[3]

            if conf > confidence:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i, ' conf:', conf)
                count += 1

print('Number of association rules:', count)
# Out:
# Frequent LHS count: 14
# Boyhood | Inside Out | The Imitation Game -> Big Hero 6  conf: 0.6730769230769231
# Boyhood | Inside Out | The Imitation Game -> Gone Girl  conf: 0.8076923076923077
# Boyhood | Gone Girl | Inside Out -> Big Hero 6  conf: 0.6296296296296297
# Boyhood | Gone Girl | Inside Out -> The Imitation Game  conf: 0.7777777777777778
# Boyhood | Fury | The Imitation Game -> Big Hero 6  conf: 0.6511627906976745
# Boyhood | Fury | The Imitation Game -> Gone Girl  conf: 0.9069767441860465
# Boyhood | Fury | Gone Girl -> Big Hero 6  conf: 0.627906976744186
# Boyhood | Fury | Gone Girl -> The Imitation Game  conf: 0.9069767441860465
# Big Hero 6 | Boyhood | The Imitation Game -> Inside Out  conf: 0.6140350877192983
# Big Hero 6 | Boyhood | The Imitation Game -> Gone Girl  conf: 0.8070175438596491
# Big Hero 6 | Boyhood | Gone Girl -> The Imitation Game  conf: 0.8214285714285714
# Big Hero 6 | Boyhood | Gone Girl -> Inside Out  conf: 0.6071428571428571
# Big Hero 6 | Gone Girl | Inside Out -> The Imitation Game  conf: 0.6941176470588235
# Big Hero 6 | Fury | The Imitation Game -> Boyhood  conf: 0.6363636363636364
# Big Hero 6 | Fury | The Imitation Game -> Inside Out  conf: 0.6363636363636364
# Big Hero 6 | Fury | The Imitation Game -> Gone Girl  conf: 0.8181818181818182
# Big Hero 6 | Fury | Gone Girl -> Boyhood  conf: 0.627906976744186
# Big Hero 6 | Fury | Gone Girl -> The Imitation Game  conf: 0.8372093023255814
# Big Hero 6 | Fury | Gone Girl -> Inside Out  conf: 0.6744186046511628
# Number of association rules: 19

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side
support = 0.05
liftthresh = 18.0

# Compute frequent item-sets of three items (LHS candidates)
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])
print('Frequent LHS count:', len(frequentLHS))

# Find RHS items with sufficient lift
count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            # Intersection of LHS (3 items) and RHS (1 item)
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            conf = common / lhs[3]
            rhs_support = len(Mitems[i])/Mnumtrans

            lift = conf / rhs_support

            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i, ' lift:', lift)
                count += 1

print('Number of association rules:', count)
# Out:
# Frequent LHS count: 6
# Fury | Gone Girl | The Imitation Game -> Catch Hell  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Deadly Virtues: Love.Honour.Obey.  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Flowers in the Attic  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Whitey: United States of America v. James J. Bulger  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> The Humbling  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> I'll See You in My Dreams  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Outcast  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Time Out of Mind  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Far from Men  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Exists  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Gangster Payday  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Final Girl  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Skin Trade  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> The Vatican Tapes  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Sinister 2  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Break Point  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> Preggoland  lift: 19.742857142857144
# Fury | Gone Girl | The Imitation Game -> The Christmas Secret  lift: 19.742857142857144
# Number of association rules: 18
